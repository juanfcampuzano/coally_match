# %%
import requests
from pymongo import MongoClient
from bson import ObjectId

# %%
client = MongoClient("mongodb+srv://danielCTO:S3cure-2024Co4llyn3w@coally.nqokc.mongodb.net/CoallyProd?authSource=admin&replicaSet=atlas-39r1if-shard-0&w=majority&readPreference=primary&retryWrites=true&ssl=true")

# %%
db = client["CoallyProd"]
projects = db["projects"]
users = db["users"]

# %%
project = projects.find_one({"_id": ObjectId("663a68401c3346001ae8136d")})

# %%
cv_ids = [str(users.find_one({"_id":id_user}).get("cv_file")) for id_user in project["aplicantes"]]

# %%
responses = [requests.post("http://localhost:8000/api/resume", json={"uniandes":False, "id_cv":cv}) for cv in cv_ids]
